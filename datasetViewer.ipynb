# %%
import pandas as pd
df = pd.read_csv("data/labeled_labeled_cleaned_company_reputation_data_samsung_posts.csv")
df[df["isRelevant"] == "irrelevant"].head()
# Out:
#                                                  text  \
# 7   So there was a bit more collaboration than tha...
# 30                            So many pictures lost..
# 39                                Captured the moment
# 41  Long story short, I was struggling to hold on ...
# 52  MAJOR UPDATE 6:20PM EST 08/02/2024: Intel, as ...
#
#                                                 title  upvotes  type  \
# 7   My buddy said "Build a computer for my daughte...    40946  post
# 30  BF's kid busted my still working 12 year old p...     9287  post
# 39                         Capturing the moment #RDDT     6567  post
# 41  So this year was the worst year of my life, ne...     6223  post
# 52  Intel has denied two of my 14900K RMAs (instab...     5340  post
#
#                          date           post_flair user_flair       subreddit  \
# 7   2025-01-09T21:42:36-05:00  Build/Battlestation        NaN    pcmasterrace
# ...

# %%
df[df["sentiment"] == "negative"].head()
# Out:
#                                                  text  \
# 0   Have a Samsung smart TVs with ads that were an...
# 1   Have a Samsung smart TVs with ads that were an...
# 2   The fact that they marketed this as revolution...
# 17  Listen people complaining about buying the Swi...
# 20  **This post has been updated with several addi...
#
#                                                 title  upvotes  type  \
# 0   YSK if you own a Samsung smart TV that has ads...    94902  post
# 1   LPT: If you own a Samsung smart TV that has ad...    82194  post
# 2   Asked Samsung's AI to remove the black car in ...    58987  post
# 17  You really didn’t make a bad choice buying the...    17114  post
# 20  Samsung "space zoom" moon shots are fake, and ...    15282  post
#
#                          date   post_flair user_flair          subreddit  \
# 0   2020-05-20T04:17:22-04:00   Technology        NaN      YouShouldKnow
# 1   2021-08-04T16:08:49-04:00  Electronics        NaN        LifeProTips
# ...

# %%
df[df["sentiment"] == "positive"].head()
# Out:
#                                                   text  \
# 15   Been a Samsung guy and every time I've upgrade...
# 91   I've used Android phones all my life, mostly S...
# 96   I swear, it's the best phone-camera that I've ...
# 121  About a month I decided to go back to Android ...
# 125  I've been loving my Flip 5 over the past month...
#
#                                                  title  upvotes  type  \
# 15   Why doesn't Apple include a charger when I dro...    20086  post
# 91   Switched to iPhone After Years of Android, Her...     2742  post
# 96   New photos from my S24U (do swipe and take a l...     2544  post
# 121     Switched back to android after 10 years of ios     1642  post
# 125  Someone next to me on my morning commute asked...     1615  post
#
#                           date   post_flair       user_flair  \
# 15   2022-03-07T10:26:47-05:00          NaN              NaN
# 91   2025-01-21T17:36:22-05:00        OneUI              NaN
# ...

# %%
pd.set_option('display.max_colwidth', None)
print(df[df["isRelevant"] == "irrelevant"][["text","subreddit"]].head())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
""
